# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
from keras.models import model_from_yaml
import os
from keras.models import load_model

batch_size=15
#FAST_RUN = False
#IMAGE_WIDTH=128
#IMAGE_HEIGHT=128
#IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
#IMAGE_CHANNELS=3
# Out:
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
test_filenames = os.listdir("test/test")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "test/test", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 80 images.

# %%
model1 = load_model('model1.h5')

# %%
predict = model1.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
threshold = 0.5
test_df['probability'] = predict
test_df['category'] = np.where(test_df['probability'] > threshold, 1,0)

# %%
test_df
# Out:
#                       filename  probability  category
# 0        no.1232no821 拷貝 2.jpg          1.0         1
# 1             no.1232no822.jpg          1.0         1
# 2        yes._yes23208yes6.jpg          1.0         1
# 3        no.1232no821 拷貝 3.jpg          1.0         1
# 4        yes._yes23208yes4.jpg          1.0         1
# 5             no.1232no821.jpg          1.0         1
# 6   yes._yes23208yes5 拷貝 3.jpg          1.0         1
# 7   yes._yes23208yes4 拷貝 3.jpg          1.0         1
# 8     yes._yes23208yes6 拷貝.jpg          1.0         1
# 9   yes._yes23208yes4 拷貝 2.jpg          1.0         1
# 10  yes._yes23208yes5 拷貝 2.jpg          1.0         1
# 11       yes._yes23208yes5.jpg          1.0         1
# 12           no.1232no82no.jpg          1.0         1
# 13       no.1232no821 拷貝 4.jpg          1.0         1
# 14            no.1232no818.jpg          1.0         1
# 15    yes._yes23208yes4 拷貝.jpg          1.0         1
# 16  yes._yes23208yes5 拷貝 6.jpg          1.0         1
# 17  yes._yes23208yes4 拷貝 6.jpg          1.0         1
# 18        no.1232no82no 拷貝.jpg          1.0         1
# 19  yes._yes23208yes4 拷貝 7.jpg          1.0         1
# 20  yes._yes23208yes5 拷貝 7.jpg          1.0         1
# 21            no.1232no819.jpg          1.0         1
# 22       no.1232no821 拷貝 5.jpg          1.0         1
# 23       no.1232no821 拷貝 7.jpg          1.0         1
# 24       yes._yes23208yes2.jpg          1.0         1
# 25  yes._yes23208yes4 拷貝 5.jpg          1.0         1
# 26  yes._yes23208yes5 拷貝 5.jpg          1.0         1
# 27  yes._yes23208yes5 拷貝 4.jpg          1.0         1
# 28  yes._yes23208yes4 拷貝 4.jpg          1.0         1
# 29       yes._yes23208yes3.jpg          1.0         1
# ..                         ...          ...       ...
# 50         no.1232no822 拷貝.jpg          1.0         1
# 51       no.1232no818 拷貝 7.jpg          1.0         1
# 52       no.1232no819 拷貝 7.jpg          1.0         1
# 53       no.1232no819 拷貝 3.jpg          1.0         1
# 54       no.1232no818 拷貝 3.jpg          1.0         1
# 55       no.1232no818 拷貝 2.jpg          1.0         1
# 56       no.1232no819 拷貝 2.jpg          1.0         1
# 57      no.1232no82no 拷貝 2.jpg          1.0         1
# 58  yes._yes23208yes2 拷貝 3.jpg          1.0         1
# 59  yes._yes23208yes3 拷貝 3.jpg          1.0         1
# 60    yes._yes23208yes2 拷貝.jpg          1.0         1
# 61  yes._yes23208yes3 拷貝 2.jpg          1.0         1
# 62      no.1232no82no 拷貝 3.jpg          1.0         1
# 63  yes._yes23208yes2 拷貝 2.jpg          1.0         1
# 64       no.1232no822 拷貝 7.jpg          1.0         1
# 65  yes._yes23208yes6 拷貝 5.jpg          1.0         1
# 66  yes._yes23208yes6 拷貝 4.jpg          1.0         1
# 67       no.1232no822 拷貝 6.jpg          1.0         1
# 68       no.1232no822 拷貝 4.jpg          1.0         1
# 69  yes._yes23208yes6 拷貝 6.jpg          1.0         1
# 70  yes._yes23208yes6 拷貝 7.jpg          1.0         1
# 71       no.1232no822 拷貝 5.jpg          1.0         1
# 72  yes._yes23208yes6 拷貝 3.jpg          1.0         1
# 73  yes._yes23208yes6 拷貝 2.jpg          1.0         1
# 74       no.1232no822 拷貝 2.jpg          1.0         1
# 75    yes._yes23208yes5 拷貝.jpg          1.0         1
# 76       no.1232no822 拷貝 3.jpg          1.0         1
# 77         no.1232no819 拷貝.jpg          1.0         1
# 78    yes._yes23208yes3 拷貝.jpg          1.0         1
# 79         no.1232no821 拷貝.jpg          1.0         1
#
# [80 rows x 3 columns]

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)
